# %%
import networkx as nx
import matplotlib.pyplot as plt
from util import load_graph
from communities import process_negative_influence_score, process_louvine

# %%
Graphs = load_graph("data/soc-redditHyperlinks-title.tsv", group_by_year=True)
print(Graphs)

for year in Graphs:
    if year == 2013:
        continue
    ego_donald = nx.ego_graph(Graphs[year], "the_donald")
    process_negative_influence_score(ego_donald)
# Out:
# {2013: <networkx.classes.digraph.DiGraph object at 0x281d633d0>, 2014: <networkx.classes.digraph.DiGraph object at 0x285bef790>, 2016: <networkx.classes.digraph.DiGraph object at 0x285bee260>, 2015: <networkx.classes.digraph.DiGraph object at 0x285bee860>, 2017: <networkx.classes.digraph.DiGraph object at 0x285bed870>}
# {}
# ...

# %%
Graphs = load_graph("data/soc-redditHyperlinks-title.tsv", group_by_year=True)

def negativity_score_per_year(Graphs, node):
    for year in Graphs:
        if year == 2013 or year == 2014 or year == 2015:
            continue
        print(Graphs[year])
        process_negative_influence_score(Graphs[year])

# %%
G = load_graph("data/soc-redditHyperlinks-title.tsv")
process_louvine(G)
# Out:
# starting louvain
# louvain finished
# ...

# %%
nx.write_gexf(G, "network.gexf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sjoerdhilhorst/ComputerScience/2023-2024/social network analysis/sna/statistics.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/sjoerdhilhorst/ComputerScience/2023-2024/social%20network%20analysis/sna/statistics.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> nx.write_gexf(G, "network.gexf")
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:5, in argmap_write_gexf_1(G, path, encoding, prettyprint, version)
#       3 import gzip
#       4 import inspect
# ----> 5 import itertools
#       6 import re
#       7 from collections import defaultdict
#
# File /opt/homebrew/lib/python3.10/site-packages/networkx/readwrite/gexf.py:86, in write_gexf(G, path, encoding, prettyprint, version)
#      37 """Write G in GEXF format to path.
#      38
# ...
